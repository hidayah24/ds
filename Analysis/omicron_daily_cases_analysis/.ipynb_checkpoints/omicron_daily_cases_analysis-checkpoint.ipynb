# %% [markdown]
# <h1 align="center">Omicron Daily Cases Analysis</h1>
# This dataset from this link : <a href="https://www.kaggle.com/yamqwe/omicron-covid19-variant-daily-cases">Kaggle</a> </br>
# <h2>Description</h2>
# <h3>Tracking the progression of the new omicron COVID-19 variant</h3>
# <h4>The data</h4>
# <ul>
#     <li>location- this is the country for which the variants information is provided</li>
#     <li>date - date for the data entry</li>
#     <li>variant - this is the variant corresponding to this data entry</li>
#     <li>num_sequences - the number of sequences processed (for the country, variant and date)</li>
#     <li>perc_sequences - percentage of sequences from the total number of sequences (for the country, variant and date)</li>
#     <li>numsequencestotal - total number of sequences (for the country, variant and date)</li>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("covid-variants.csv")
df.head()
# Out:
#   location        date    variant  num_sequences  perc_sequences  \
# 0   Angola  2020-07-06      Alpha              0             0.0
# 1   Angola  2020-07-06  B.1.1.277              0             0.0
# 2   Angola  2020-07-06  B.1.1.302              0             0.0
# 3   Angola  2020-07-06  B.1.1.519              0             0.0
# 4   Angola  2020-07-06    B.1.160              0             0.0
#
#    num_sequences_total
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %%
df["variant"].unique()
# Out:
# array(['Alpha', 'B.1.1.277', 'B.1.1.302', 'B.1.1.519', 'B.1.160',
#        'B.1.177', 'B.1.221', 'B.1.258', 'B.1.367', 'B.1.620', 'Beta',
#        'Delta', 'Epsilon', 'Eta', 'Gamma', 'Iota', 'Kappa', 'Lambda',
#        'Mu', 'Omicron', 'S:677H.Robin1', 'S:677P.Pelican', 'others',
#        'non_who'], dtype=object)

# %%
df.shape
# Out:
# (98784, 6)

# %%
df2 = df[df["variant"] == "Omicron"]
df2.head()
# Out:
#     location        date  variant  num_sequences  perc_sequences  \
# 19    Angola  2020-07-06  Omicron              0             0.0
# 43    Angola  2020-08-31  Omicron              0             0.0
# 67    Angola  2020-09-28  Omicron              0             0.0
# 91    Angola  2020-10-12  Omicron              0             0.0
# 115   Angola  2020-10-26  Omicron              0             0.0
#
#      num_sequences_total
# 19                     3
# 43                     1
# 67                    10
# 91                    29
# 115                    7

# %%
df3 = df2.drop(['variant'],axis=1)
df3.head()
# Out:
#     location        date  num_sequences  perc_sequences  num_sequences_total
# 19    Angola  2020-07-06              0             0.0                    3
# 43    Angola  2020-08-31              0             0.0                    1
# 67    Angola  2020-09-28              0             0.0                   10
# 91    Angola  2020-10-12              0             0.0                   29
# 115   Angola  2020-10-26              0             0.0                    7

# %%
import pycountry as pyc

# %%
def iso_code(df):
    input_countries = df['location'].tolist()
    countries = {}
    for country in pyc.countries:
        countries[country.name] = country.alpha_3
        codes = [countries.get(country, 'Unknown code') for country in input_countries]
    return codes

# %%
iso = iso_code(df3)
iso
# Out:
# ['AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'AGO',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'ABW',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BHR',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BGD',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BEL',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BLZ',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BEN',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BIH',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BWA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'BRA',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'KHM',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CMR',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'COL',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'CRI',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'HRV',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'Unknown code',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CYP',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'CZE',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DNK',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DJI',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'DOM',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'ECU',
#  'EGY',
#  'EGY',
#  'EGY',
#  'EGY',
#  'EGY',
#  'EGY',
#  'EGY',
#  ...]

# %%
df4 = df3.copy()
df4['iso_code'] = iso
df4.head()
# Out:
#     location        date  num_sequences  perc_sequences  num_sequences_total  \
# 19    Angola  2020-07-06              0             0.0                    3
# 43    Angola  2020-08-31              0             0.0                    1
# 67    Angola  2020-09-28              0             0.0                   10
# 91    Angola  2020-10-12              0             0.0                   29
# 115   Angola  2020-10-26              0             0.0                    7
#
#     iso_code
# 19       AGO
# 43       AGO
# 67       AGO
# 91       AGO
# 115      AGO

# %%
import plotly.express as px
import plotly.offline as py

virus_map = px.choropleth(df4, locations = 'iso_code', color = 'num_sequences_total')
virus_map.update_layout(height=500, margin={"r":0,"t":0,"l":0,"b":0})
virus_map.show()
# Out:
# <div>                            <div id="527837d4-8d59-4fe2-b7b1-5845532759cc" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("527837d4-8d59-4fe2-b7b1-5845532759cc")) {                    Plotly.newPlot(                        "527837d4-8d59-4fe2-b7b1-5845532759cc",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"iso_code=%{location}<br>num_sequences_total=%{z}<extra></extra>","locations":["AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","AGO","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ARG","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","ABW","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUS","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","AUT","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BHR","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BGD","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BEL","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BLZ","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BEN","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BIH","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BWA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","BRA","Unknown code","Unknown code","Unknown code","Unknown code","Unknown code","Unknown code","Unknown code","Unknown code","Unknown code","Unknown code","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","BGR","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","KHM","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR","CMR"," ...
