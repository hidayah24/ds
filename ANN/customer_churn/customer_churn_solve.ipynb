# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("customer_churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID', axis='columns', inplace=True)
df.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 3652  Female              1      No         No       1           No
# 5265  Female              0      No         No      66          Yes
# 3541  Female              0     Yes         No      49           No
# 4057  Female              0     Yes        Yes      72          Yes
# 1454    Male              0     Yes        Yes      29          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 3652  No phone service             DSL                   No
# 5265               Yes     Fiber optic                   No
# 3541  No phone service             DSL                  Yes
# 4057               Yes              No  No internet service
# 1454                No              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 3652                   No                   No                   No
# 5265                  Yes                   No                   No
# 3541                   No                   No                   No
# 4057  No internet service  No internet service  No internet service
# 1454  No internet service  No internet service  No internet service
#
#               StreamingTV      StreamingMovies        Contract  \
# 3652                   No                   No  Month-to-month
# 5265                  Yes                   No        One year
# 3541                  Yes                   No  Month-to-month
# 4057  No internet service  No internet service        Two year
# 1454  No internet service  No internet service  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 3652               No           Electronic check           25.25        25.25
# 5265              Yes  Bank transfer (automatic)           88.90       6000.1
# 3541               No  Bank transfer (automatic)           40.65      2070.75
# 4057               No               Mailed check           24.90       1859.2
# 1454              Yes               Mailed check           20.65       654.85
#
#      Churn
# 3652   Yes
# 5265    No
# 3541    No
# 4057    No
# 1454    No

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric(df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-06ba430a4ba5> in <module>
# ----> 1 pd.to_numeric(df.TotalCharges)
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " " at position 488

# %%
pd.to_numeric(df.TotalCharges,errors='coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# 753                 No              No  No internet service
# 936                 No             DSL                  Yes
# 1082               Yes              No  No internet service
# 1340  No phone service             DSL                  Yes
# 3331                No              No  No internet service
# 3826               Yes              No  No internet service
# 4380                No              No  No internet service
# 5218                No              No  No internet service
# 6670               Yes             DSL                   No
# 6754               Yes             DSL                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 488                    No                  Yes                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                   No
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                  Yes                  Yes                  Yes
# 6754                  Yes                   No                  Yes
#
#               StreamingTV      StreamingMovies  Contract PaperlessBilling  \
# 488                   Yes                   No  Two year              Yes
# 753   No internet service  No internet service  Two year               No
# 936                   Yes                  Yes  Two year               No
# 1082  No internet service  No internet service  Two year               No
# 1340                  Yes                   No  Two year               No
# 3331  No internet service  No internet service  Two year               No
# 3826  No internet service  No internet service  Two year               No
# 4380  No internet service  No internet service  Two year               No
# 5218  No internet service  No internet service  One year              Yes
# 6670                  Yes                   No  Two year               No
# 6754                   No                   No  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %%
df.iloc[488]['TotalCharges']
# Out:
# ' '

# %%
df.shape
# Out:
# (7043, 20)

# %%
df2 = df[df.TotalCharges!=' ']
df2.shape
# Out:
# (7032, 20)

# %%
df2.TotalCharges = pd.to_numeric(df2.TotalCharges)
# Out:
# C:\Users\Taufik\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df2.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
tenure_churn_no = df2[df2.Churn=='No'].tenure
tenure_churn_yes = df2[df2.Churn=='Yes'].tenure
plt.figure(figsize=(8, 6))
plt.ylabel("Number of Customers")
plt.xlabel("tenure")
plt.title("Customer Churn Visualiztion")
plt.hist([tenure_churn_yes,tenure_churn_no], color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
tenure_churn_no = df2[df2.Churn=='No'].MonthlyCharges
tenure_churn_yes = df2[df2.Churn=='Yes'].MonthlyCharges
plt.figure(figsize=(8, 6))
plt.ylabel("Number of Customers")
plt.xlabel("Monthly Charges")
plt.title("Customer Churn Visualiztion")
plt.hist([tenure_churn_yes,tenure_churn_no], color=['green','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
def print_unique_values(df):
    for column in df:
        if df[column].dtypes=='object':
            print(f'{column} : {df2[column].unique()}')

# %%
print_unique_values(df2)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
df2.replace('No phone service','No',inplace=True)
df2.replace('No internet service','No',inplace=True)
# Out:
# C:\Users\Taufik\anaconda3\lib\site-packages\pandas\core\frame.py:4379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
print_unique_values(df2)
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn : ['No' 'Yes']

# %%
yes_no_column = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_column:
    df2[col].replace({'Yes': 1,'No': 0}, inplace=True)
# Out:
# C:\Users\Taufik\anaconda3\lib\site-packages\pandas\core\series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
for column in df2:
    print(f'{column} : {df2[column].unique()}')
# Out:
# gender : ['Female' 'Male']
# SeniorCitizen : [0 1]
# Partner : [1 0]
# Dependents : [0 1]
# tenure : [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService : [0 1]
# MultipleLines : [0 1]
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : [0 1]
# OnlineBackup : [1 0]
# DeviceProtection : [0 1]
# TechSupport : [0 1]
# StreamingTV : [0 1]
# StreamingMovies : [0 1]
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : [1 0]
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges : [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges : [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn : [0 1]

# %%
df2.replace({'Female': 1, 'Male': 0}, inplace=True)
# Out:
# C:\Users\Taufik\anaconda3\lib\site-packages\pandas\core\frame.py:4379: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
df2.gender.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df3 = pd.get_dummies(data=df2, columns=['InternetService','Contract','PaymentMethod'])
df3.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3631       1              1        1           0       1             1
# 3092       1              0        0           0       1             0
# 1507       0              0        0           0      54             1
# 6663       1              0        0           0       1             1
# 3712       0              0        0           0      44             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 3631              0               1             0                 0  ...
# 3092              0               0             0                 0  ...
# 1507              0               0             0                 0  ...
# 6663              0               0             0                 0  ...
# 3712              0               1             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 3631                    1                            0                   0
# 3092                    1                            0                   0
# 1507                    0                            0                   1
# 6663                    1                            0                   0
# 3712                    1                            0                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 3631                        1                  0                  0
# 3092                        1                  0                  0
# 1507                        0                  0                  1
# 6663                        1                  0                  0
# 3712                        0                  1                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 3631                                        0
# 3092                                        0
# 1507                                        0
# 6663                                        0
# 3712                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 3631                                      0                               1
# 3092                                      0                               0
# 1507                                      1                               0
# 6663                                      0                               1
# 3712                                      0                               1
#
#       PaymentMethod_Mailed check
# 3631                           0
# 3092                           1
# 1507                           0
# 6663                           0
# 3712                           0
#
# [5 rows x 27 columns]

# %%
df3.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df3[cols_to_scale] = scaler.fit_transform(df3[cols_to_scale])
df3.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 2318       1              0        1           1  0.985915             1
# 1838       0              1        0           0  0.746479             1
# 5999       0              0        0           0  0.478873             1
# 5776       0              0        1           0  1.000000             1
# 6552       1              1        0           0  0.014085             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 2318              1               1             1                 1  ...
# 1838              1               0             1                 0  ...
# 5999              1               1             0                 1  ...
# 5776              1               1             1                 1  ...
# 6552              0               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 2318                    0                            1                   0
# 1838                    0                            1                   0
# 5999                    0                            1                   0
# 5776                    1                            0                   0
# 6552                    0                            1                   0
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 2318                        0                  0                  1
# 1838                        1                  0                  0
# 5999                        0                  0                  1
# 5776                        0                  0                  1
# 6552                        1                  0                  0
#
#       PaymentMethod_Bank transfer (automatic)  \
# 2318                                        1
# 1838                                        0
# 5999                                        0
# 5776                                        1
# 6552                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 2318                                      0                               0
# 1838                                      0                               1
# 5999                                      0                               1
# 5776                                      0                               0
# 6552                                      0                               0
#
#       PaymentMethod_Mailed check
# 2318                           0
# 1838                           0
# 5999                           0
# 5776                           0
# 6552                           0
#
# [5 rows x 27 columns]

# %%
for column in df3:
    print(f'{column} : {df3[column].unique()}')
# Out:
# gender : [1 0]
# SeniorCitizen : [0 1]
# Partner : [1 0]
# Dependents : [0 1]
# tenure : [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService : [0 1]
# MultipleLines : [0 1]
# OnlineSecurity : [0 1]
# OnlineBackup : [1 0]
# DeviceProtection : [0 1]
# TechSupport : [0 1]
# StreamingTV : [0 1]
# StreamingMovies : [0 1]
# PaperlessBilling : [1 0]
# MonthlyCharges : [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges : [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn : [0 1]
# InternetService_DSL : [1 0]
# InternetService_Fiber optic : [0 1]
# InternetService_No : [0 1]
# Contract_Month-to-month : [1 0]
# Contract_One year : [0 1]
# Contract_Two year : [0 1]
# PaymentMethod_Bank transfer (automatic) : [0 1]
# PaymentMethod_Credit card (automatic) : [0 1]
# PaymentMethod_Electronic check : [1 0]
# PaymentMethod_Mailed check : [0 1]

# %%
x = df3.drop('Churn', axis='columns')
y = df3['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=5)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5625, 26)
# (1407, 26)

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(26,), activation='relu'),
    keras.layers.Dense(1, activation='sigmoid',)
])

model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 5s 3ms/step - loss: 0.4749 - accuracy: 0.7676
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4243 - accuracy: 0.7954
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4179 - accuracy: 0.7982
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4150 - accuracy: 0.8036
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4139 - accuracy: 0.8041
# Epoch 6/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4121 - accuracy: 0.8041
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8073
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8068
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4095 - accuracy: 0.8085
# Epoch 10/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4076 - accuracy: 0.8055
# Epoch 11/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4082 - accuracy: 0.8101
# Epoch 12/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4066 - accuracy: 0.8094
# Epoch 13/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4064 - accuracy: 0.8108
# Epoch 14/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4057 - accuracy: 0.8091
# Epoch 15/100
# 176/176 [==============================] - ETA: 0s - loss: 0.4054 - accuracy: 0.81 - 0s 1ms/step - loss: 0.4055 - accuracy: 0.8110
# Epoch 16/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4042 - accuracy: 0.8108
# Epoch 17/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4032 - accuracy: 0.8123
# Epoch 18/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4032 - accuracy: 0.8100
# Epoch 19/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4031 - accuracy: 0.8094
# Epoch 20/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8130
# Epoch 21/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.8128
# Epoch 22/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4009 - accuracy: 0.8128
# Epoch 23/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4002 - accuracy: 0.8123
# Epoch 24/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4002 - accuracy: 0.8117
# Epoch 25/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8133
# Epoch 26/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3987 - accuracy: 0.8126
# Epoch 27/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3980 - accuracy: 0.8119
# Epoch 28/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8140
# Epoch 29/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3976 - accuracy: 0.8114
# Epoch 30/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8128
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3958 - accuracy: 0.8133
# Epoch 32/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3960 - accuracy: 0.8112
# Epoch 33/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3948 - accuracy: 0.8137
# Epoch 34/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8128
# Epoch 35/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8158
# Epoch 36/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.8130
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3937 - accuracy: 0.8135
# Epoch 38/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3926 - accuracy: 0.8149
# Epoch 39/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.8137
# Epoch 40/100
# 176/176 [==============================] - ETA: 0s - loss: 0.3937 - accuracy: 0.81 - 0s 2ms/step - loss: 0.3926 - accuracy: 0.8158
# Epoch 41/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3917 - accuracy: 0.8135
# Epoch 42/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.8169
# Epoch 43/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3912 - accuracy: 0.8169
# Epoch 44/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3911 - accuracy: 0.8162
# Epoch 45/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3906 - accuracy: 0.8164
# Epoch 46/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3898 - accuracy: 0.8160
# Epoch 47/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3883 - accuracy: 0.8164
# Epoch 48/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3892 - accuracy: 0.8180
# Epoch 49/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.8181
# Epoch 50/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3891 - accuracy: 0.8169
# Epoch 51/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3885 - accuracy: 0.8187
# Epoch 52/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3880 - accuracy: 0.8172
# Epoch 53/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3891 - accuracy: 0.8160
# Epoch 54/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3879 - accuracy: 0.8178
# Epoch 55/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3879 - accuracy: 0.8162
# Epoch 56/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3867 - accuracy: 0.8180
# Epoch 57/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3875 - accuracy: 0.8160
# Epoch 58/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3867 - accuracy: 0.8185
# Epoch 59/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3863 - accuracy: 0.8172
# Epoch 60/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3860 - accuracy: 0.8172
# Epoch 61/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3857 - accuracy: 0.8171
# Epoch 62/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3857 - accuracy: 0.8151
# Epoch 63/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3862 - accuracy: 0.8174
# Epoch 64/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3851 - accuracy: 0.8188
# Epoch 65/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3853 - accuracy: 0.8172
# Epoch 66/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3849 - accuracy: 0.8160
# Epoch 67/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3846 - accuracy: 0.8180
# Epoch 68/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3855 - accuracy: 0.8155
# Epoch 69/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3849 - accuracy: 0.8194
# Epoch 70/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.8180
# Epoch 71/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3846 - accuracy: 0.8194
# Epoch 72/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3839 - accuracy: 0.8192
# Epoch 73/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3838 - accuracy: 0.8203
# Epoch 74/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3845 - accuracy: 0.8180
# Epoch 75/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3839 - accuracy: 0.8183
# Epoch 76/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3836 - accuracy: 0.8171
# Epoch 77/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3833 - accuracy: 0.8178
# Epoch 78/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3835 - accuracy: 0.8180
# Epoch 79/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3834 - accuracy: 0.8176
# Epoch 80/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3830 - accuracy: 0.8194
# Epoch 81/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3828 - accuracy: 0.8201
# Epoch 82/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3829 - accuracy: 0.8167
# Epoch 83/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3826 - accuracy: 0.8201
# Epoch 84/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3826 - accuracy: 0.8185
# Epoch 85/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3823 - accuracy: 0.8213
# Epoch 86/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3822 - accuracy: 0.8180
# Epoch 87/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3820 - accuracy: 0.8187
# Epoch 88/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3824 - accuracy: 0.8206
# Epoch 89/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3824 - accuracy: 0.8206
# Epoch 90/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3824 - accuracy: 0.8169
# Epoch 91/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3812 - accuracy: 0.8222
# Epoch 92/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3816 - accuracy: 0.8165
# Epoch 93/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3814 - accuracy: 0.8185
# Epoch 94/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3809 - accuracy: 0.8206
# Epoch 95/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3811 - accuracy: 0.8201
# Epoch 96/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3820 - accuracy: 0.8180
# Epoch 97/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3813 - accuracy: 0.8196
# Epoch 98/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3812 - accuracy: 0.8188
# Epoch 99/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3804 - accuracy: 0.8197
# Epoch 100/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3803 - accuracy: 0.8222

# %%
model.evaluate(X_test,y_test)
# Out:
# 44/44 [==============================] - 0s 929us/step - loss: 0.4609 - accuracy: 0.7825
# [0.46085238456726074, 0.7825160026550293]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# array([[0.19864714],
#        [0.5361997 ],
#        [0.02633178],
#        [0.7676085 ],
#        [0.6360816 ]], dtype=float32)

# %%
y_test[:5]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# Name: Churn, dtype: int64

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:5]
# Out:
# [0, 1, 0, 1, 1]

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       999
#            1       0.63      0.62      0.62       408
#
#     accuracy                           0.78      1407
#    macro avg       0.74      0.73      0.74      1407
# weighted avg       0.78      0.78      0.78      1407

# %%
import seaborn as sns
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
